# %% [markdown]
# <a href="https://colab.research.google.com/github/pejmanrasti/FormationUnivAngers/blob/main/Jour3/Apple_detection_Transferlearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Hands-on**: **Training via transfer learning, a UNET model for  Apple Detection**

# %% [markdown]
# # **U-Net (2D)**
# ---
#
# <font size = 4>U-Net is an encoder-decoder network architecture originally used for image segmentation, first published by [Ronneberger *et al.*](https://arxiv.org/abs/1505.04597). The first half of the U-Net architecture is a downsampling convolutional neural network which acts as a feature extractor from input images. The other half upsamples these results and restores an image by combining results from downsampling with the upsampled images.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Step 0: Important note**
#
#   <font size = 4> 1. Before you run the notebook, please ensure that you are logged into your Google account and have the data to process in your Google Drive.
#
#   <font size = 4> 2. Check for GPU access: Go to **Runtime -> Change the Runtime type**
#
#
#   <font size = 4> 3. If you wish to train the network using your own dataset, please change the path of your data specified in **Step 3**
#
#
# <font size = 4> 4. **Download your saved model(s) from Google Drive or change the name of new trained model otherwise the saved files will be erased**

# %% [markdown]
# ## Step 0.1: Mount your Google Drive

# %%
# mount user's Google Drive to Google Colab.
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # **Step 1. Install U-Net dependencies**

# %%
# !pip install q keras==2.3.0
# !pip install tensorflow-gpu==2.0.0


import os
import cv2
import shutil
import sys
import random
import pandas as pd
import numpy as np
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import pickle
from tqdm import tqdm
import h5py
from PIL import Image
from IPython.display import display, HTML 
from itertools import chain
from tqdm import tqdm_notebook, tnrange
# **********************************************
from keras.optimizers import Adam, RMSprop
from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda, Reshape, Permute, Activation
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
from keras.callbacks import TensorBoard
import tensorflow as tf
from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose,UpSampling2D
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.losses import binary_crossentropy
from keras.models import load_model


from skimage.io import imread, imshow, concatenate_images
from skimage import color
from skimage.transform import resize
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img



# %matplotlib inline
# !pip install -U segmentation-models
# Out:
# Collecting q
#   Downloading https://files.pythonhosted.org/packages/53/bc/51619d89e0bd855567e7652fa16d06f1ed36a85f108a7fe71f6629bf719d/q-2.6-py2.py3-none-any.whl
# Collecting keras==2.3.0
#   Downloading https://files.pythonhosted.org/packages/1b/18/2e1ef121e5560ac24c7ac9e363aa5fa7006c40563c989e7211aba95b793a/Keras-2.3.0-py2.py3-none-any.whl (377kB)
#      |████████████████████████████████| 378kB 7.2MB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.0) (1.1.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.3.0) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.0) (1.18.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.3.0) (3.13)
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 7.5MB/s
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.0) (1.4.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.3.0) (1.15.0)
# Installing collected packages: q, keras-applications, keras
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.3.0 keras-applications-1.0.8 q-2.6
# Collecting tensorflow-gpu==2.0.0
#   Downloading https://files.pythonhosted.org/packages/25/44/47f0722aea081697143fbcf5d2aa60d1aee4aaacb5869aee2b568974777b/tensorflow_gpu-2.0.0-cp36-cp36m-manylinux2010_x86_64.whl (380.8MB)
#      |████████████████████████████████| 380.8MB 37kB/s
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (1.0.8)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (1.12.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (3.3.0)
# Collecting tensorflow-estimator<2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/fc/08/8b927337b7019c374719145d1dceba21a8bb909b93b1ad6f8fb7d22c1ca1/tensorflow_estimator-2.0.1-py2.py3-none-any.whl (449kB)
#      |████████████████████████████████| 450kB 53.0MB/s
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (3.12.4)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (1.1.0)
# Collecting tensorboard<2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/76/54/99b9d5d52d5cb732f099baaaf7740403e83fe6b0cedde940fabd2b13d75a/tensorboard-2.0.2-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 54.3MB/s
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (0.2.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (0.8.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (0.10.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (1.33.2)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (1.18.5)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (1.1.2)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0) (0.35.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==2.0.0) (2.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==2.0.0) (50.3.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (3.3.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (0.4.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (1.17.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (2.23.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (2.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (1.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (4.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (2020.11.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (3.4.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (0.4.8)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7542 sha256=d33c98840493fa26fffdefc82f3e30d12d60f4e6473ed3c09333625808ce7905
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 2.3.0 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.3.0 has requirement tensorboard<3,>=2.3.0, but you'll have tensorboard 2.0.2 which is incompatible.
# ERROR: tensorflow 2.3.0 has requirement tensorflow-estimator<2.4.0,>=2.3.0, but you'll have tensorflow-estimator 2.0.1 which is incompatible.
# ERROR: tensorflow-probability 0.11.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# Installing collected packages: tensorflow-estimator, tensorboard, gast, tensorflow-gpu
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
# Successfully installed gast-0.2.2 tensorboard-2.0.2 tensorflow-estimator-2.0.1 tensorflow-gpu-2.0.0
# Using TensorFlow backend.
# Collecting segmentation-models
#   Downloading https://files.pythonhosted.org/packages/da/b9/4a183518c21689a56b834eaaa45cad242d9ec09a4360b5b10139f23c63f4/segmentation_models-1.0.1-py3-none-any.whl
# Collecting image-classifiers==1.0.0
#   Downloading https://files.pythonhosted.org/packages/81/98/6f84720e299a4942ab80df5f76ab97b7828b24d1de5e9b2cbbe6073228b7/image_classifiers-1.0.0-py3-none-any.whl
# Collecting efficientnet==1.0.0
#   Downloading https://files.pythonhosted.org/packages/97/82/f3ae07316f0461417dc54affab6e86ab188a5a22f33176d35271628b96e0/efficientnet-1.0.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from segmentation-models) (1.0.8)
# Requirement already satisfied, skipping upgrade: scikit-image in /usr/local/lib/python3.6/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.16.2)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (2.10.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.18.5)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (7.0.0)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.2.2)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.5)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.1.1)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.4.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.15.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.4.7)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (1.3.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.8.1)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image->efficientnet==1.0.0->segmentation-models) (4.4.2)
# Installing collected packages: image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 segmentation-models-1.0.1

# %%
import segmentation_models as sm

if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
    

seed = 42
random.seed = seed
np.random.seed = seed
# Out:
# Segmentation Models: using `keras` framework.
# Default GPU Device: /device:GPU:0

# %% [markdown]
# # **Step 2: Functions**

# %%
def background(mask):
    backgr = np.logical_not(mask)
    return backgr

def rgb_to_gray(img):
        gray = np.zeros(img.shape)
        R = np.array(img[:, :, 0])
        G = np.array(img[:, :, 1])
        B = np.array(img[:, :, 2])        

        for i in range(3):
           gray[:,:,i] = R *.299 + G *.587 + B *.114

        return gray 
    
def show_images(images,titles=None):
    """Display a list of images"""
    n_ims = len(images)
    if titles is None: titles = ['(%d)' % i for i in range(1,n_ims + 1)]
    fig = plt.figure(figsize=(20, 10))
    n = 1
    for image,title in zip(images,titles):
        a = fig.add_subplot(1,n_ims,n) # Make subplot
        a.grid(False)
        #plt.imshow(image, cmap=plt.cm.nipy_spectral)
        plt.imshow(image, cmap = plt.cm.gray)
        a.set_title(title)
        n += 1
    plt.show()

def dice_coef(y_true, y_pred):
    eps = 1e-6
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection) / (K.sum(y_true_f * y_true_f) + K.sum(y_pred_f * y_pred_f) + eps)

def performance(y_pred, y_true):
    TP = sum(sum(y_pred * y_true))
    FP = sum(sum(y_pred - y_pred * y_true))
    FN = sum(sum(y_true - y_pred * y_true))
    TPR = TP/(TP+FN)
    PPV = TP/(TP+FP)
    return (TPR, PPV)

# %% [markdown]
# # **Step3: Reading DATA**

# %%
pickle_in = open("/content/gdrive/MyDrive/Longlifetraining/Apple_detection/RGB_dataset_apples_for_deepJ.pickle","rb")
RGB_image = pickle.load(pickle_in)

pickle_in = open("/content/gdrive/MyDrive/Longlifetraining/Apple_detection/BW_labels_dataset_apples_for_deepJ.pickle","rb")
Mask = pickle.load(pickle_in)
Mask=np.array(Mask)


print('RGB images shape is',RGB_image.shape)
print('Masks shape is' ,Mask.shape)
# Out:
# RGB images shape is (670, 224, 224, 3)
# Masks shape is (670, 224, 224, 1)

# %% [markdown]
# # **Step 4: Shuffle, Split DATA and Display images and masks**

# %%
#shuffle
idx = np.random.permutation(len(RGB_image))
RGB_image, Mask = RGB_image[idx], Mask[idx]

#train data
RGB_image_train=RGB_image[:500] 
Mask_train=Mask[:500]

#validation data
RGB_image_valid=RGB_image[500:600]
Mask_valid=Mask[500:600]

#test data
RGB_image_test=RGB_image[600:670]
Mask_test=Mask[600:670]

print('Total number of Training DATA: ', len(RGB_image_train))
print('Total number of Validation DATA: ', len(RGB_image_valid))
print('Total number of test DATA: ', len(RGB_image_test))
# Out:
# Total number of Training DATA:  500
# Total number of Validation DATA:  100
# Total number of test DATA:  70

# %% [markdown]
# ## Show Images

# %%
ix = 10
show_images(images = [RGB_image_train[ix,:,:,:], Mask_train[ix,:,:,0], background(Mask_train[ix,:,:,0])], 
            titles = ['RGB image', 'label Apple', 'label Background'])
show_images(images = [RGB_image_valid[ix,:,:,:], Mask_valid[ix,:,:,0], background(Mask_valid[ix,:,:,0])], 
            titles = ['RGB image', 'label Apple', 'label Background'])
show_images(images = [RGB_image_test[ix,:,:,:], Mask_test[ix,:,:,0], background(Mask_test[ix,:,:,0])], 
            titles = ['RGB image', 'label Apple', 'label Background'])

# %% [markdown]
# # **Step 5: Perform Data augmentation: albumentation library**

# %%
from albumentations import (VerticalFlip, HorizontalFlip, Flip, RandomRotate90, Rotate, ShiftScaleRotate, CenterCrop, OpticalDistortion,                              
                            ElasticTransform, JpegCompression, HueSaturationValue, GridDistortion,
                            RGBShift, RandomBrightness, RandomContrast, Blur, MotionBlur, MedianBlur, GaussNoise, CLAHE, ChannelShuffle, 
                            InvertImg, RandomGamma, ToGray, PadIfNeeded, RandomCrop, Compose, Transpose, RandomSizedCrop, OneOf, Normalize)

import segmentation_models as sm

# %%
IMG_HEIGHT=224
IMG_WIDTH=224
IMG_CHANNELS=3
LABEL_CHANNELS=1

aug_proportion = 4 #how much are we increasing the data set example 4 means each image will have 4 correpondants synthetic images

n_aug = int(len(RGB_image_train) * aug_proportion)
X_aug = np.zeros((n_aug, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
Y_aug = np.zeros((n_aug, IMG_HEIGHT, IMG_WIDTH, LABEL_CHANNELS), dtype=np.bool)


aug = Compose([HorizontalFlip(p=0.8),
               VerticalFlip(p=0.7),
               RandomBrightness(p=0.8, limit=0.2),
               RandomContrast(p=0.5, limit=0.2),
               RandomRotate90(p=0.6),
            ])


for i in range(0,int(len(RGB_image_train))):
        j=aug_proportion*i
        for z in range(0,aug_proportion):
              step=(z+j)
              augmented = aug(image=np.float32(RGB_image_train[i]), mask=Mask_train[i]*1)
              X_aug[step] = augmented['image']
              Y_aug[step] = augmented['mask']
  


RGB_image_train_aug = np.append(RGB_image_train, X_aug, axis=0)
Mask_train_aug = np.append(Mask_train, Y_aug, axis=0)

#shuffling
idx = np.random.permutation(len(RGB_image_train_aug))
RGB_image_train_aug, Mask_train_aug = RGB_image_train_aug[idx], Mask_train_aug[idx]

print("Training images (size+shape): ", RGB_image_train_aug.shape)
print("Training masks (size+shape): ", Mask_train_aug.shape)
# Out:
# X_train:  (2500, 224, 224, 3)
# Y_train:  (2500, 224, 224, 1)

# %% [markdown]
# ## Show Images

# %%
ix = 0 #index for real images
ixx=3 # index for augmented images
show_images(images = [RGB_image_train[ix,:,:,:], X_aug[ixx,:,:,:], Mask_train[ix,:,:,0],  Y_aug[ixx,:,:,0]],
            titles = ['Original Image', 'Transormed Image', 'Original Mask', 'Transformed Mask'])

# %% [markdown]
# # **Step 6: Defining U-Net model**
# ---

# %% [markdown]
# ## A. Model

# %%
BACKBONE = 'vgg19'
model = sm.Unet(backbone_name=BACKBONE, encoder_weights='imagenet', activation='sigmoid')
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 2s 0us/step

# %% [markdown]
# ## B. Loss

# %%
Loss_function=binary_crossentropy

# %% [markdown]
#  ## C. Metrics

# %%
metrics_list = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5), dice_coef, 'binary_accuracy']

# %% [markdown]
#  ## D. Callbacks

# %%
from tensorflow import keras
from keras.callbacks import LearningRateScheduler

class LossHistory_(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.lr = []
        
    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        self.lr.append(exp_decay(len(self.losses)))
        print('lr:', exp_decay(len(self.losses)))

def exp_decay(epoch):
    initial_lrate = 0.1
    k = 0.1
    lrate = initial_lrate * np.exp(-k*epoch)
    return lrate

# learning schedule callback
loss_history_ = LossHistory_()
lrate_ = LearningRateScheduler(exp_decay)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=10, verbose=1, mode='auto', min_delta=0.0001, cooldown=5, min_lr=0.0001)
Name_of_the_model_saved='/content/gdrive/MyDrive/Longlifetraining/Apple_detection/AppleDetection_best_model_pretrained_test1.h5' #You can should this part of the path /content/gdrive/MyDrive/Longlifetraining/Apple_detection
early = EarlyStopping(monitor="val_loss", mode="min", patience=15)
checkpoint = ModelCheckpoint(Name_of_the_model_saved, verbose=1, save_best_only=True)
callbacks_list = [loss_history_, lrate_,checkpoint, early, reduceLROnPlat]

# %% [markdown]
#  ## E. Model Parameters

# %%
BATCH_SIZE = 5
EPOCHS = 100 
optim = Adam(0, decay = 1e-6)

# %% [markdown]
#  ## F. Model train

# %%
model.compile(optim, loss = Loss_function , metrics=metrics_list)
history = model.fit(RGB_image_train, Mask_train, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(RGB_image_valid, Mask_valid),verbose=1,callbacks=callbacks_list)
# Out:
# Train on 500 samples, validate on 100 samples
# Epoch 1/100
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1296 - iou_score: 4.1562e-04 - f1-score: 7.9807e-04 - dice_coef: 0.0568 - binary_accuracy: 0.9686 - val_loss: 0.4526 - val_iou_score: 1.5780e-09 - val_f1-score: 1.5780e-09 - val_dice_coef: 0.0976 - val_binary_accuracy: 0.9711
# lr: 0.09048374180359596
#
# Epoch 00001: val_loss improved from inf to 0.45257, saving model to AppleDetection_best_model.h5
# Epoch 2/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.1168 - iou_score: 1.7435e-09 - f1-score: 1.7435e-09 - dice_coef: 0.0614 - binary_accuracy: 0.9741 - val_loss: 0.1321 - val_iou_score: 1.5780e-09 - val_f1-score: 1.5780e-09 - val_dice_coef: 0.0973 - val_binary_accuracy: 0.9711
# lr: 0.0818730753077982
#
# Epoch 00002: val_loss improved from 0.45257 to 0.13210, saving model to AppleDetection_best_model.h5
# Epoch 3/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0953 - iou_score: 1.7288e-09 - f1-score: 1.7288e-09 - dice_coef: 0.2048 - binary_accuracy: 0.9741 - val_loss: 0.1146 - val_iou_score: 1.5780e-09 - val_f1-score: 1.5780e-09 - val_dice_coef: 0.1028 - val_binary_accuracy: 0.9711
# lr: 0.0740818220681718
#
# Epoch 00003: val_loss improved from 0.13210 to 0.11464, saving model to AppleDetection_best_model.h5
# Epoch 4/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0636 - iou_score: 0.0775 - f1-score: 0.1203 - dice_coef: 0.4634 - binary_accuracy: 0.9753 - val_loss: 0.1220 - val_iou_score: 8.2331e-05 - val_f1-score: 1.6459e-04 - val_dice_coef: 0.0870 - val_binary_accuracy: 0.9711
# lr: 0.06703200460356394
#
# Epoch 00004: val_loss did not improve from 0.11464
# Epoch 5/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0569 - iou_score: 0.3340 - f1-score: 0.4962 - dice_coef: 0.5429 - binary_accuracy: 0.9792 - val_loss: 0.1055 - val_iou_score: 0.0425 - val_f1-score: 0.0808 - val_dice_coef: 0.2033 - val_binary_accuracy: 0.9722
# lr: 0.06065306597126335
#
# Epoch 00005: val_loss improved from 0.11464 to 0.10549, saving model to AppleDetection_best_model.h5
# Epoch 6/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0529 - iou_score: 0.3776 - f1-score: 0.5448 - dice_coef: 0.5826 - binary_accuracy: 0.9805 - val_loss: 0.0996 - val_iou_score: 0.0705 - val_f1-score: 0.1305 - val_dice_coef: 0.2691 - val_binary_accuracy: 0.9729
# lr: 0.05488116360940264
#
# Epoch 00006: val_loss improved from 0.10549 to 0.09957, saving model to AppleDetection_best_model.h5
# Epoch 7/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0509 - iou_score: 0.4039 - f1-score: 0.5709 - dice_coef: 0.6078 - binary_accuracy: 0.9813 - val_loss: 0.0700 - val_iou_score: 0.2470 - val_f1-score: 0.3948 - val_dice_coef: 0.4804 - val_binary_accuracy: 0.9774
# lr: 0.04965853037914095
#
# Epoch 00007: val_loss improved from 0.09957 to 0.07005, saving model to AppleDetection_best_model.h5
# Epoch 8/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0469 - iou_score: 0.4438 - f1-score: 0.6116 - dice_coef: 0.6446 - binary_accuracy: 0.9826 - val_loss: 0.0587 - val_iou_score: 0.2878 - val_f1-score: 0.4433 - val_dice_coef: 0.5351 - val_binary_accuracy: 0.9784
# lr: 0.044932896411722156
#
# Epoch 00008: val_loss improved from 0.07005 to 0.05874, saving model to AppleDetection_best_model.h5
# Epoch 9/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0464 - iou_score: 0.4510 - f1-score: 0.6192 - dice_coef: 0.6567 - binary_accuracy: 0.9826 - val_loss: 0.0520 - val_iou_score: 0.4019 - val_f1-score: 0.5719 - val_dice_coef: 0.6214 - val_binary_accuracy: 0.9815
# lr: 0.04065696597405991
#
# Epoch 00009: val_loss improved from 0.05874 to 0.05199, saving model to AppleDetection_best_model.h5
# Epoch 10/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0448 - iou_score: 0.4638 - f1-score: 0.6315 - dice_coef: 0.6682 - binary_accuracy: 0.9832 - val_loss: 0.0565 - val_iou_score: 0.3975 - val_f1-score: 0.5659 - val_dice_coef: 0.6138 - val_binary_accuracy: 0.9813
# lr: 0.036787944117144235
#
# Epoch 00010: val_loss did not improve from 0.05199
# Epoch 11/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0448 - iou_score: 0.4726 - f1-score: 0.6395 - dice_coef: 0.6763 - binary_accuracy: 0.9834 - val_loss: 0.0460 - val_iou_score: 0.4966 - val_f1-score: 0.6627 - val_dice_coef: 0.6966 - val_binary_accuracy: 0.9836
# lr: 0.03328710836980796
#
# Epoch 00011: val_loss improved from 0.05199 to 0.04597, saving model to AppleDetection_best_model.h5
# Epoch 12/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0420 - iou_score: 0.4922 - f1-score: 0.6580 - dice_coef: 0.6949 - binary_accuracy: 0.9842 - val_loss: 0.0458 - val_iou_score: 0.4614 - val_f1-score: 0.6298 - val_dice_coef: 0.6773 - val_binary_accuracy: 0.9829
# lr: 0.030119421191220203
#
# Epoch 00012: val_loss improved from 0.04597 to 0.04579, saving model to AppleDetection_best_model.h5
# Epoch 13/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0417 - iou_score: 0.4957 - f1-score: 0.6611 - dice_coef: 0.6995 - binary_accuracy: 0.9844 - val_loss: 0.0444 - val_iou_score: 0.5376 - val_f1-score: 0.6988 - val_dice_coef: 0.7299 - val_binary_accuracy: 0.9836
# lr: 0.02725317930340126
#
# Epoch 00013: val_loss improved from 0.04579 to 0.04441, saving model to AppleDetection_best_model.h5
# Epoch 14/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0404 - iou_score: 0.5080 - f1-score: 0.6723 - dice_coef: 0.7108 - binary_accuracy: 0.9848 - val_loss: 0.0429 - val_iou_score: 0.5242 - val_f1-score: 0.6871 - val_dice_coef: 0.7228 - val_binary_accuracy: 0.9840
# lr: 0.024659696394160643
#
# Epoch 00014: val_loss improved from 0.04441 to 0.04288, saving model to AppleDetection_best_model.h5
# Epoch 15/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0397 - iou_score: 0.5170 - f1-score: 0.6802 - dice_coef: 0.7185 - binary_accuracy: 0.9851 - val_loss: 0.0461 - val_iou_score: 0.5267 - val_f1-score: 0.6893 - val_dice_coef: 0.7226 - val_binary_accuracy: 0.9839
# lr: 0.022313016014842982
#
# Epoch 00015: val_loss did not improve from 0.04288
# Epoch 16/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0401 - iou_score: 0.5145 - f1-score: 0.6775 - dice_coef: 0.7166 - binary_accuracy: 0.9849 - val_loss: 0.0420 - val_iou_score: 0.5030 - val_f1-score: 0.6681 - val_dice_coef: 0.7116 - val_binary_accuracy: 0.9842
# lr: 0.02018965179946554
#
# Epoch 00016: val_loss improved from 0.04288 to 0.04197, saving model to AppleDetection_best_model.h5
# Epoch 17/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0389 - iou_score: 0.5201 - f1-score: 0.6823 - dice_coef: 0.7219 - binary_accuracy: 0.9854 - val_loss: 0.0413 - val_iou_score: 0.5494 - val_f1-score: 0.7086 - val_dice_coef: 0.7441 - val_binary_accuracy: 0.9843
# lr: 0.018268352405273462
#
# Epoch 00017: val_loss improved from 0.04197 to 0.04131, saving model to AppleDetection_best_model.h5
# Epoch 18/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0387 - iou_score: 0.5259 - f1-score: 0.6878 - dice_coef: 0.7278 - binary_accuracy: 0.9854 - val_loss: 0.0412 - val_iou_score: 0.5177 - val_f1-score: 0.6811 - val_dice_coef: 0.7229 - val_binary_accuracy: 0.9844
# lr: 0.016529888822158653
#
# Epoch 00018: val_loss improved from 0.04131 to 0.04119, saving model to AppleDetection_best_model.h5
# Epoch 19/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0386 - iou_score: 0.5296 - f1-score: 0.6908 - dice_coef: 0.7303 - binary_accuracy: 0.9855 - val_loss: 0.0504 - val_iou_score: 0.5297 - val_f1-score: 0.6918 - val_dice_coef: 0.7278 - val_binary_accuracy: 0.9802
# lr: 0.014956861922263504
#
# Epoch 00019: val_loss did not improve from 0.04119
# Epoch 20/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0389 - iou_score: 0.5263 - f1-score: 0.6870 - dice_coef: 0.7279 - binary_accuracy: 0.9854 - val_loss: 0.0559 - val_iou_score: 0.4779 - val_f1-score: 0.6454 - val_dice_coef: 0.6829 - val_binary_accuracy: 0.9835
# lr: 0.013533528323661271
#
# Epoch 00020: val_loss did not improve from 0.04119
# Epoch 21/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0378 - iou_score: 0.5319 - f1-score: 0.6929 - dice_coef: 0.7343 - binary_accuracy: 0.9857 - val_loss: 0.0396 - val_iou_score: 0.5610 - val_f1-score: 0.7182 - val_dice_coef: 0.7546 - val_binary_accuracy: 0.9849
# lr: 0.012245642825298192
#
# Epoch 00021: val_loss improved from 0.04119 to 0.03957, saving model to AppleDetection_best_model.h5
# Epoch 22/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0370 - iou_score: 0.5419 - f1-score: 0.7017 - dice_coef: 0.7412 - binary_accuracy: 0.9860 - val_loss: 0.0408 - val_iou_score: 0.5575 - val_f1-score: 0.7153 - val_dice_coef: 0.7527 - val_binary_accuracy: 0.9846
# lr: 0.011080315836233388
#
# Epoch 00022: val_loss did not improve from 0.03957
# Epoch 23/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0370 - iou_score: 0.5440 - f1-score: 0.7032 - dice_coef: 0.7435 - binary_accuracy: 0.9860 - val_loss: 0.0403 - val_iou_score: 0.5644 - val_f1-score: 0.7210 - val_dice_coef: 0.7583 - val_binary_accuracy: 0.9844
# lr: 0.010025884372280372
#
# Epoch 00023: val_loss did not improve from 0.03957
# Epoch 24/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0369 - iou_score: 0.5443 - f1-score: 0.7039 - dice_coef: 0.7438 - binary_accuracy: 0.9861 - val_loss: 0.0411 - val_iou_score: 0.5707 - val_f1-score: 0.7263 - val_dice_coef: 0.7621 - val_binary_accuracy: 0.9842
# lr: 0.009071795328941248
#
# Epoch 00024: val_loss did not improve from 0.03957
# Epoch 25/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0365 - iou_score: 0.5467 - f1-score: 0.7057 - dice_coef: 0.7461 - binary_accuracy: 0.9862 - val_loss: 0.0394 - val_iou_score: 0.5739 - val_f1-score: 0.7290 - val_dice_coef: 0.7658 - val_binary_accuracy: 0.9848
# lr: 0.008208499862389881
#
# Epoch 00025: val_loss improved from 0.03957 to 0.03941, saving model to AppleDetection_best_model.h5
# Epoch 26/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0360 - iou_score: 0.5518 - f1-score: 0.7099 - dice_coef: 0.7496 - binary_accuracy: 0.9864 - val_loss: 0.0395 - val_iou_score: 0.5411 - val_f1-score: 0.7013 - val_dice_coef: 0.7427 - val_binary_accuracy: 0.9853
# lr: 0.007427357821433388
#
# Epoch 00026: val_loss did not improve from 0.03941
# Epoch 27/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0358 - iou_score: 0.5570 - f1-score: 0.7145 - dice_coef: 0.7541 - binary_accuracy: 0.9865 - val_loss: 0.0413 - val_iou_score: 0.5716 - val_f1-score: 0.7270 - val_dice_coef: 0.7637 - val_binary_accuracy: 0.9838
# lr: 0.006720551273974976
#
# Epoch 00027: val_loss did not improve from 0.03941
# Epoch 28/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0354 - iou_score: 0.5567 - f1-score: 0.7140 - dice_coef: 0.7538 - binary_accuracy: 0.9866 - val_loss: 0.0382 - val_iou_score: 0.5776 - val_f1-score: 0.7318 - val_dice_coef: 0.7691 - val_binary_accuracy: 0.9853
# lr: 0.006081006262521796
#
# Epoch 00028: val_loss improved from 0.03941 to 0.03825, saving model to AppleDetection_best_model.h5
# Epoch 29/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0356 - iou_score: 0.5575 - f1-score: 0.7147 - dice_coef: 0.7552 - binary_accuracy: 0.9865 - val_loss: 0.0381 - val_iou_score: 0.5717 - val_f1-score: 0.7271 - val_dice_coef: 0.7652 - val_binary_accuracy: 0.9856
# lr: 0.005502322005640721
#
# Epoch 00029: val_loss improved from 0.03825 to 0.03811, saving model to AppleDetection_best_model.h5
# Epoch 30/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0352 - iou_score: 0.5575 - f1-score: 0.7146 - dice_coef: 0.7551 - binary_accuracy: 0.9866 - val_loss: 0.0379 - val_iou_score: 0.5723 - val_f1-score: 0.7275 - val_dice_coef: 0.7660 - val_binary_accuracy: 0.9857
# lr: 0.004978706836786395
#
# Epoch 00030: val_loss improved from 0.03811 to 0.03786, saving model to AppleDetection_best_model.h5
# Epoch 31/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0349 - iou_score: 0.5644 - f1-score: 0.7205 - dice_coef: 0.7602 - binary_accuracy: 0.9867 - val_loss: 0.0375 - val_iou_score: 0.5703 - val_f1-score: 0.7258 - val_dice_coef: 0.7645 - val_binary_accuracy: 0.9858
# lr: 0.00450492023935578
#
# Epoch 00031: val_loss improved from 0.03786 to 0.03747, saving model to AppleDetection_best_model.h5
# Epoch 32/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0349 - iou_score: 0.5649 - f1-score: 0.7209 - dice_coef: 0.7603 - binary_accuracy: 0.9868 - val_loss: 0.0380 - val_iou_score: 0.5739 - val_f1-score: 0.7287 - val_dice_coef: 0.7668 - val_binary_accuracy: 0.9857
# lr: 0.0040762203978366215
#
# Epoch 00032: val_loss did not improve from 0.03747
# Epoch 33/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0347 - iou_score: 0.5663 - f1-score: 0.7221 - dice_coef: 0.7620 - binary_accuracy: 0.9868 - val_loss: 0.0389 - val_iou_score: 0.5833 - val_f1-score: 0.7364 - val_dice_coef: 0.7730 - val_binary_accuracy: 0.9852
# lr: 0.0036883167401239995
#
# Epoch 00033: val_loss did not improve from 0.03747
# Epoch 34/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0347 - iou_score: 0.5654 - f1-score: 0.7212 - dice_coef: 0.7608 - binary_accuracy: 0.9869 - val_loss: 0.0380 - val_iou_score: 0.5849 - val_f1-score: 0.7378 - val_dice_coef: 0.7748 - val_binary_accuracy: 0.9854
# lr: 0.003337326996032607
#
# Epoch 00034: val_loss did not improve from 0.03747
# Epoch 35/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0346 - iou_score: 0.5652 - f1-score: 0.7209 - dice_coef: 0.7609 - binary_accuracy: 0.9869 - val_loss: 0.0373 - val_iou_score: 0.5788 - val_f1-score: 0.7327 - val_dice_coef: 0.7715 - val_binary_accuracy: 0.9858
# lr: 0.00301973834223185
#
# Epoch 00035: val_loss improved from 0.03747 to 0.03726, saving model to AppleDetection_best_model.h5
# Epoch 36/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0343 - iou_score: 0.5676 - f1-score: 0.7231 - dice_coef: 0.7631 - binary_accuracy: 0.9870 - val_loss: 0.0372 - val_iou_score: 0.5735 - val_f1-score: 0.7285 - val_dice_coef: 0.7682 - val_binary_accuracy: 0.9858
# lr: 0.0027323722447292562
#
# Epoch 00036: val_loss improved from 0.03726 to 0.03724, saving model to AppleDetection_best_model.h5
# Epoch 37/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0341 - iou_score: 0.5724 - f1-score: 0.7269 - dice_coef: 0.7667 - binary_accuracy: 0.9870 - val_loss: 0.0377 - val_iou_score: 0.5869 - val_f1-score: 0.7393 - val_dice_coef: 0.7763 - val_binary_accuracy: 0.9855
# lr: 0.002472352647033939
#
# Epoch 00037: val_loss did not improve from 0.03724
# Epoch 38/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0343 - iou_score: 0.5704 - f1-score: 0.7257 - dice_coef: 0.7657 - binary_accuracy: 0.9870 - val_loss: 0.0376 - val_iou_score: 0.5875 - val_f1-score: 0.7398 - val_dice_coef: 0.7772 - val_binary_accuracy: 0.9855
# lr: 0.002237077185616559
#
# Epoch 00038: val_loss did not improve from 0.03724
# Epoch 39/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0341 - iou_score: 0.5712 - f1-score: 0.7261 - dice_coef: 0.7657 - binary_accuracy: 0.9871 - val_loss: 0.0373 - val_iou_score: 0.5834 - val_f1-score: 0.7365 - val_dice_coef: 0.7748 - val_binary_accuracy: 0.9858
# lr: 0.002024191144580438
#
# Epoch 00039: val_loss did not improve from 0.03724
# Epoch 40/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0338 - iou_score: 0.5726 - f1-score: 0.7272 - dice_coef: 0.7668 - binary_accuracy: 0.9871 - val_loss: 0.0372 - val_iou_score: 0.5865 - val_f1-score: 0.7390 - val_dice_coef: 0.7771 - val_binary_accuracy: 0.9857
# lr: 0.001831563888873418
#
# Epoch 00040: val_loss improved from 0.03724 to 0.03719, saving model to AppleDetection_best_model.h5
# Epoch 41/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0338 - iou_score: 0.5736 - f1-score: 0.7284 - dice_coef: 0.7679 - binary_accuracy: 0.9872 - val_loss: 0.0379 - val_iou_score: 0.5902 - val_f1-score: 0.7420 - val_dice_coef: 0.7791 - val_binary_accuracy: 0.9854
# lr: 0.001657267540176124
#
# Epoch 00041: val_loss did not improve from 0.03719
# Epoch 42/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0338 - iou_score: 0.5745 - f1-score: 0.7289 - dice_coef: 0.7688 - binary_accuracy: 0.9872 - val_loss: 0.0374 - val_iou_score: 0.5764 - val_f1-score: 0.7307 - val_dice_coef: 0.7697 - val_binary_accuracy: 0.9860
# lr: 0.0014995576820477704
#
# Epoch 00042: val_loss did not improve from 0.03719
# Epoch 43/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0338 - iou_score: 0.5772 - f1-score: 0.7310 - dice_coef: 0.7708 - binary_accuracy: 0.9872 - val_loss: 0.0368 - val_iou_score: 0.5868 - val_f1-score: 0.7392 - val_dice_coef: 0.7773 - val_binary_accuracy: 0.9859
# lr: 0.0013568559012200935
#
# Epoch 00043: val_loss improved from 0.03719 to 0.03685, saving model to AppleDetection_best_model.h5
# Epoch 44/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0338 - iou_score: 0.5756 - f1-score: 0.7298 - dice_coef: 0.7695 - binary_accuracy: 0.9872 - val_loss: 0.0369 - val_iou_score: 0.5858 - val_f1-score: 0.7384 - val_dice_coef: 0.7766 - val_binary_accuracy: 0.9859
# lr: 0.0012277339903068436
#
# Epoch 00044: val_loss did not improve from 0.03685
# Epoch 45/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0336 - iou_score: 0.5772 - f1-score: 0.7310 - dice_coef: 0.7703 - binary_accuracy: 0.9873 - val_loss: 0.0367 - val_iou_score: 0.5881 - val_f1-score: 0.7403 - val_dice_coef: 0.7783 - val_binary_accuracy: 0.9859
# lr: 0.0011108996538242307
#
# Epoch 00045: val_loss improved from 0.03685 to 0.03674, saving model to AppleDetection_best_model.h5
# Epoch 46/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0334 - iou_score: 0.5803 - f1-score: 0.7335 - dice_coef: 0.7729 - binary_accuracy: 0.9873 - val_loss: 0.0367 - val_iou_score: 0.5854 - val_f1-score: 0.7381 - val_dice_coef: 0.7771 - val_binary_accuracy: 0.9860
# lr: 0.0010051835744633575
#
# Epoch 00046: val_loss improved from 0.03674 to 0.03673, saving model to AppleDetection_best_model.h5
# Epoch 47/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0335 - iou_score: 0.5755 - f1-score: 0.7294 - dice_coef: 0.7697 - binary_accuracy: 0.9873 - val_loss: 0.0366 - val_iou_score: 0.5850 - val_f1-score: 0.7378 - val_dice_coef: 0.7769 - val_binary_accuracy: 0.9860
# lr: 0.0009095277101695816
#
# Epoch 00047: val_loss improved from 0.03673 to 0.03660, saving model to AppleDetection_best_model.h5
# Epoch 48/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0336 - iou_score: 0.5777 - f1-score: 0.7315 - dice_coef: 0.7708 - binary_accuracy: 0.9872 - val_loss: 0.0367 - val_iou_score: 0.5871 - val_f1-score: 0.7395 - val_dice_coef: 0.7784 - val_binary_accuracy: 0.9859
# lr: 0.0008229747049020024
#
# Epoch 00048: val_loss did not improve from 0.03660
# Epoch 49/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0337 - iou_score: 0.5756 - f1-score: 0.7296 - dice_coef: 0.7698 - binary_accuracy: 0.9872 - val_loss: 0.0367 - val_iou_score: 0.5872 - val_f1-score: 0.7396 - val_dice_coef: 0.7786 - val_binary_accuracy: 0.9860
# lr: 0.0007446583070924339
#
# Epoch 00049: val_loss did not improve from 0.03660
# Epoch 50/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0336 - iou_score: 0.5771 - f1-score: 0.7310 - dice_coef: 0.7703 - binary_accuracy: 0.9873 - val_loss: 0.0367 - val_iou_score: 0.5903 - val_f1-score: 0.7420 - val_dice_coef: 0.7799 - val_binary_accuracy: 0.9859
# lr: 0.0006737946999085467
#
# Epoch 00050: val_loss did not improve from 0.03660
# Epoch 51/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0331 - iou_score: 0.5788 - f1-score: 0.7324 - dice_coef: 0.7724 - binary_accuracy: 0.9874 - val_loss: 0.0367 - val_iou_score: 0.5882 - val_f1-score: 0.7403 - val_dice_coef: 0.7789 - val_binary_accuracy: 0.9860
# lr: 0.0006096746565515633
#
# Epoch 00051: val_loss did not improve from 0.03660
# Epoch 52/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0333 - iou_score: 0.5800 - f1-score: 0.7334 - dice_coef: 0.7729 - binary_accuracy: 0.9873 - val_loss: 0.0367 - val_iou_score: 0.5896 - val_f1-score: 0.7415 - val_dice_coef: 0.7793 - val_binary_accuracy: 0.9859
# lr: 0.0005516564420760772
#
# Epoch 00052: val_loss did not improve from 0.03660
# Epoch 53/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0334 - iou_score: 0.5786 - f1-score: 0.7323 - dice_coef: 0.7720 - binary_accuracy: 0.9873 - val_loss: 0.0366 - val_iou_score: 0.5886 - val_f1-score: 0.7407 - val_dice_coef: 0.7794 - val_binary_accuracy: 0.9860
# lr: 0.0004991593906910213
#
# Epoch 00053: val_loss did not improve from 0.03660
# Epoch 54/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0332 - iou_score: 0.5783 - f1-score: 0.7319 - dice_coef: 0.7716 - binary_accuracy: 0.9874 - val_loss: 0.0366 - val_iou_score: 0.5895 - val_f1-score: 0.7414 - val_dice_coef: 0.7800 - val_binary_accuracy: 0.9860
# lr: 0.0004516580942612666
#
# Epoch 00054: val_loss did not improve from 0.03660
# Epoch 55/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0333 - iou_score: 0.5791 - f1-score: 0.7326 - dice_coef: 0.7724 - binary_accuracy: 0.9873 - val_loss: 0.0365 - val_iou_score: 0.5841 - val_f1-score: 0.7370 - val_dice_coef: 0.7768 - val_binary_accuracy: 0.9860
# lr: 0.00040867714384640666
#
# Epoch 00055: val_loss improved from 0.03660 to 0.03649, saving model to AppleDetection_best_model.h5
# Epoch 56/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0332 - iou_score: 0.5784 - f1-score: 0.7320 - dice_coef: 0.7719 - binary_accuracy: 0.9874 - val_loss: 0.0365 - val_iou_score: 0.5838 - val_f1-score: 0.7367 - val_dice_coef: 0.7763 - val_binary_accuracy: 0.9861
# lr: 0.0003697863716482929
#
# Epoch 00056: val_loss improved from 0.03649 to 0.03648, saving model to AppleDetection_best_model.h5
# Epoch 57/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0333 - iou_score: 0.5793 - f1-score: 0.7327 - dice_coef: 0.7723 - binary_accuracy: 0.9874 - val_loss: 0.0365 - val_iou_score: 0.5873 - val_f1-score: 0.7396 - val_dice_coef: 0.7786 - val_binary_accuracy: 0.9860
# lr: 0.0003345965457471272
#
# Epoch 00057: val_loss did not improve from 0.03648
# Epoch 58/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0332 - iou_score: 0.5818 - f1-score: 0.7346 - dice_coef: 0.7743 - binary_accuracy: 0.9874 - val_loss: 0.0365 - val_iou_score: 0.5849 - val_f1-score: 0.7376 - val_dice_coef: 0.7772 - val_binary_accuracy: 0.9860
# lr: 0.0003027554745375813
#
# Epoch 00058: val_loss did not improve from 0.03648
# Epoch 59/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0332 - iou_score: 0.5793 - f1-score: 0.7328 - dice_coef: 0.7723 - binary_accuracy: 0.9874 - val_loss: 0.0365 - val_iou_score: 0.5870 - val_f1-score: 0.7394 - val_dice_coef: 0.7784 - val_binary_accuracy: 0.9860
# lr: 0.00027394448187683686
#
# Epoch 00059: val_loss did not improve from 0.03648
# Epoch 60/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0333 - iou_score: 0.5796 - f1-score: 0.7330 - dice_coef: 0.7729 - binary_accuracy: 0.9874 - val_loss: 0.0365 - val_iou_score: 0.5880 - val_f1-score: 0.7402 - val_dice_coef: 0.7792 - val_binary_accuracy: 0.9860
# lr: 0.00024787521766663585
#
# Epoch 00060: val_loss did not improve from 0.03648
# Epoch 61/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0334 - iou_score: 0.5800 - f1-score: 0.7332 - dice_coef: 0.7729 - binary_accuracy: 0.9873 - val_loss: 0.0365 - val_iou_score: 0.5866 - val_f1-score: 0.7391 - val_dice_coef: 0.7783 - val_binary_accuracy: 0.9860
# lr: 0.00022428677194858012
#
# Epoch 00061: val_loss improved from 0.03648 to 0.03648, saving model to AppleDetection_best_model.h5
# Epoch 62/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0332 - iou_score: 0.5796 - f1-score: 0.7329 - dice_coef: 0.7723 - binary_accuracy: 0.9874 - val_loss: 0.0365 - val_iou_score: 0.5875 - val_f1-score: 0.7397 - val_dice_coef: 0.7788 - val_binary_accuracy: 0.9860
# lr: 0.00020294306362957342
#
# Epoch 00062: val_loss did not improve from 0.03648
# Epoch 63/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0331 - iou_score: 0.5797 - f1-score: 0.7331 - dice_coef: 0.7730 - binary_accuracy: 0.9874 - val_loss: 0.0365 - val_iou_score: 0.5867 - val_f1-score: 0.7391 - val_dice_coef: 0.7784 - val_binary_accuracy: 0.9860
# lr: 0.00018363047770289057
#
# Epoch 00063: val_loss did not improve from 0.03648
# Epoch 64/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0333 - iou_score: 0.5781 - f1-score: 0.7319 - dice_coef: 0.7720 - binary_accuracy: 0.9873 - val_loss: 0.0365 - val_iou_score: 0.5864 - val_f1-score: 0.7389 - val_dice_coef: 0.7784 - val_binary_accuracy: 0.9860
# lr: 0.0001661557273173934
#
# Epoch 00064: val_loss improved from 0.03648 to 0.03646, saving model to AppleDetection_best_model.h5
# Epoch 65/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0333 - iou_score: 0.5820 - f1-score: 0.7351 - dice_coef: 0.7744 - binary_accuracy: 0.9874 - val_loss: 0.0365 - val_iou_score: 0.5884 - val_f1-score: 0.7405 - val_dice_coef: 0.7792 - val_binary_accuracy: 0.9860
# lr: 0.00015034391929775724
#
# Epoch 00065: val_loss did not improve from 0.03646
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 0.00013292458606883883.
# Epoch 66/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0330 - iou_score: 0.5789 - f1-score: 0.7324 - dice_coef: 0.7726 - binary_accuracy: 0.9874 - val_loss: 0.0365 - val_iou_score: 0.5843 - val_f1-score: 0.7372 - val_dice_coef: 0.7769 - val_binary_accuracy: 0.9861
# lr: 0.00013603680375478928
#
# Epoch 00066: val_loss improved from 0.03646 to 0.03645, saving model to AppleDetection_best_model.h5
# Epoch 67/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0330 - iou_score: 0.5829 - f1-score: 0.7356 - dice_coef: 0.7753 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5865 - val_f1-score: 0.7390 - val_dice_coef: 0.7784 - val_binary_accuracy: 0.9860
# lr: 0.0001230911902673481
#
# Epoch 00067: val_loss improved from 0.03645 to 0.03644, saving model to AppleDetection_best_model.h5
# Epoch 68/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0330 - iou_score: 0.5818 - f1-score: 0.7347 - dice_coef: 0.7745 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5861 - val_f1-score: 0.7386 - val_dice_coef: 0.7782 - val_binary_accuracy: 0.9861
# lr: 0.00011137751478448025
#
# Epoch 00068: val_loss improved from 0.03644 to 0.03643, saving model to AppleDetection_best_model.h5
# Epoch 69/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0332 - iou_score: 0.5797 - f1-score: 0.7330 - dice_coef: 0.7729 - binary_accuracy: 0.9874 - val_loss: 0.0365 - val_iou_score: 0.5878 - val_f1-score: 0.7400 - val_dice_coef: 0.7791 - val_binary_accuracy: 0.9860
# lr: 0.00010077854290485106
#
# Epoch 00069: val_loss did not improve from 0.03643
# Epoch 70/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0332 - iou_score: 0.5802 - f1-score: 0.7334 - dice_coef: 0.7732 - binary_accuracy: 0.9874 - val_loss: 0.0365 - val_iou_score: 0.5873 - val_f1-score: 0.7396 - val_dice_coef: 0.7788 - val_binary_accuracy: 0.9860
# lr: 9.118819655545162e-05
#
# Epoch 00070: val_loss did not improve from 0.03643
# Epoch 71/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0332 - iou_score: 0.5791 - f1-score: 0.7328 - dice_coef: 0.7724 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5871 - val_f1-score: 0.7395 - val_dice_coef: 0.7788 - val_binary_accuracy: 0.9860
# lr: 8.251049232659039e-05
#
# Epoch 00071: val_loss did not improve from 0.03643
# Epoch 72/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0331 - iou_score: 0.5813 - f1-score: 0.7343 - dice_coef: 0.7741 - binary_accuracy: 0.9874 - val_loss: 0.0365 - val_iou_score: 0.5870 - val_f1-score: 0.7394 - val_dice_coef: 0.7788 - val_binary_accuracy: 0.9860
# lr: 7.465858083766792e-05
#
# Epoch 00072: val_loss did not improve from 0.03643
# Epoch 73/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0331 - iou_score: 0.5805 - f1-score: 0.7337 - dice_coef: 0.7733 - binary_accuracy: 0.9874 - val_loss: 0.0365 - val_iou_score: 0.5881 - val_f1-score: 0.7402 - val_dice_coef: 0.7792 - val_binary_accuracy: 0.9860
# lr: 6.755387751938438e-05
#
# Epoch 00073: val_loss did not improve from 0.03643
# Epoch 74/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0332 - iou_score: 0.5811 - f1-score: 0.7340 - dice_coef: 0.7739 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5869 - val_f1-score: 0.7393 - val_dice_coef: 0.7787 - val_binary_accuracy: 0.9860
# lr: 6.112527611295723e-05
#
# Epoch 00074: val_loss did not improve from 0.03643
# Epoch 75/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0332 - iou_score: 0.5797 - f1-score: 0.7329 - dice_coef: 0.7724 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5866 - val_f1-score: 0.7390 - val_dice_coef: 0.7784 - val_binary_accuracy: 0.9861
# lr: 5.530843701478336e-05
#
# Epoch 00075: val_loss improved from 0.03643 to 0.03643, saving model to AppleDetection_best_model.h5
# Epoch 76/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0331 - iou_score: 0.5825 - f1-score: 0.7355 - dice_coef: 0.7751 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5866 - val_f1-score: 0.7391 - val_dice_coef: 0.7785 - val_binary_accuracy: 0.9861
# lr: 5.004514334406104e-05
#
# Epoch 00076: val_loss did not improve from 0.03643
# Epoch 77/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0331 - iou_score: 0.5811 - f1-score: 0.7343 - dice_coef: 0.7737 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5872 - val_f1-score: 0.7395 - val_dice_coef: 0.7788 - val_binary_accuracy: 0.9860
# lr: 4.52827182886797e-05
#
# Epoch 00077: val_loss did not improve from 0.03643
# Epoch 78/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0331 - iou_score: 0.5822 - f1-score: 0.7353 - dice_coef: 0.7749 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5871 - val_f1-score: 0.7395 - val_dice_coef: 0.7787 - val_binary_accuracy: 0.9860
# lr: 4.097349789797865e-05
#
# Epoch 00078: val_loss did not improve from 0.03643
# Epoch 79/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0331 - iou_score: 0.5817 - f1-score: 0.7347 - dice_coef: 0.7740 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5869 - val_f1-score: 0.7392 - val_dice_coef: 0.7787 - val_binary_accuracy: 0.9860
# lr: 3.7074354045908826e-05
#
# Epoch 00079: val_loss did not improve from 0.03643
# Epoch 80/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0333 - iou_score: 0.5822 - f1-score: 0.7350 - dice_coef: 0.7743 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5863 - val_f1-score: 0.7388 - val_dice_coef: 0.7784 - val_binary_accuracy: 0.9861
# lr: 3.354626279025119e-05
#
# Epoch 00080: val_loss did not improve from 0.03643
# Epoch 81/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0331 - iou_score: 0.5836 - f1-score: 0.7362 - dice_coef: 0.7755 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5880 - val_f1-score: 0.7401 - val_dice_coef: 0.7791 - val_binary_accuracy: 0.9860
# lr: 3.035391380788668e-05
#
# Epoch 00081: val_loss did not improve from 0.03643
# Epoch 82/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0331 - iou_score: 0.5805 - f1-score: 0.7338 - dice_coef: 0.7735 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5866 - val_f1-score: 0.7391 - val_dice_coef: 0.7785 - val_binary_accuracy: 0.9861
# lr: 2.7465356997214206e-05
#
# Epoch 00082: val_loss did not improve from 0.03643
# Epoch 83/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0331 - iou_score: 0.5809 - f1-score: 0.7342 - dice_coef: 0.7734 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5876 - val_f1-score: 0.7399 - val_dice_coef: 0.7791 - val_binary_accuracy: 0.9860
# lr: 2.4851682710795188e-05
#
# Epoch 00083: val_loss did not improve from 0.03643
# Epoch 84/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0331 - iou_score: 0.5807 - f1-score: 0.7340 - dice_coef: 0.7738 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5879 - val_f1-score: 0.7401 - val_dice_coef: 0.7791 - val_binary_accuracy: 0.9860
# lr: 2.248673241788482e-05
#
# Epoch 00084: val_loss did not improve from 0.03643
# Epoch 85/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0330 - iou_score: 0.5812 - f1-score: 0.7341 - dice_coef: 0.7737 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5867 - val_f1-score: 0.7391 - val_dice_coef: 0.7786 - val_binary_accuracy: 0.9860
# lr: 2.0346836901064418e-05
#
# Epoch 00085: val_loss did not improve from 0.03643
# Epoch 86/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0331 - iou_score: 0.5806 - f1-score: 0.7337 - dice_coef: 0.7736 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5877 - val_f1-score: 0.7399 - val_dice_coef: 0.7790 - val_binary_accuracy: 0.9860
# lr: 1.841057936675792e-05
#
# Epoch 00086: val_loss did not improve from 0.03643
# Epoch 87/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0332 - iou_score: 0.5814 - f1-score: 0.7346 - dice_coef: 0.7739 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5869 - val_f1-score: 0.7393 - val_dice_coef: 0.7787 - val_binary_accuracy: 0.9860
# lr: 1.6658581098763325e-05
#
# Epoch 00087: val_loss did not improve from 0.03643
# Epoch 88/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0331 - iou_score: 0.5828 - f1-score: 0.7355 - dice_coef: 0.7752 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5869 - val_f1-score: 0.7393 - val_dice_coef: 0.7787 - val_binary_accuracy: 0.9860
# lr: 1.5073307509547651e-05
#
# Epoch 00088: val_loss did not improve from 0.03643
# Epoch 89/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0331 - iou_score: 0.5825 - f1-score: 0.7353 - dice_coef: 0.7748 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5868 - val_f1-score: 0.7392 - val_dice_coef: 0.7787 - val_binary_accuracy: 0.9860
# lr: 1.363889264820114e-05
#
# Epoch 00089: val_loss did not improve from 0.03643
# Epoch 90/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0329 - iou_score: 0.5824 - f1-score: 0.7352 - dice_coef: 0.7749 - binary_accuracy: 0.9874 - val_loss: 0.0364 - val_iou_score: 0.5873 - val_f1-score: 0.7396 - val_dice_coef: 0.7789 - val_binary_accuracy: 0.9860
# lr: 1.2340980408667957e-05
#
# Epoch 00090: val_loss did not improve from 0.03643

# %% [markdown]
# # **Step 7: Assessement**

# %%
# Plot training & validation iou_score values
plt.figure(figsize=(5, 15))
plt.subplot(411)
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left') 


plt.subplot(412)
plt.plot(history.history['dice_coef'])
plt.plot(history.history['val_dice_coef'])
plt.title('Model dice_coef')
plt.ylabel('dice_coef')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left') 


plt.subplot(413)
plt.plot(history.history['f1-score'])
plt.plot(history.history['val_f1-score'])
plt.title('Model f1-score')
plt.ylabel('f1-score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(414)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot( np.argmin(history.history["val_loss"]), np.min(history.history["val_loss"]), marker="x", color="r", label="best model")
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test','best'], loc='upper left')
plt.show()

# %%
print("Val loss is ", np.min(history.history["val_loss"]))
print("Val Dice coeff is",np.max(history.history["val_dice_coef"]))
print("Val iou coeff is ", np.max(history.history["val_iou_score"]))
print("Val f1 coeff is ", np.max(history.history["val_f1-score"]))
# Out:
# Val loss is  0.03643300291150808
# Val Dice coeff is 0.7800346612930298
# Val iou coeff is  0.5902773141860962
# Val f1 coeff is  0.7419905662536621

# %% [markdown]
#  ## A. Evaluation on Test DATA - method 1

# %%
# load the best model
from keras.models import Model, load_model
Name_of_the_model_saved='/content/gdrive/MyDrive/Longlifetraining/Apple_detection/AppleDetection_best_model_pretrained_test1.h5' #You can should this part of the path /content/gdrive/MyDrive/Longlifetraining/Apple_detection
model = load_model(Name_of_the_model_saved, custom_objects={'dice_coef': dice_coef, 'iou_score': sm.metrics.IOUScore(threshold=0.5), 'f1-score': sm.metrics.FScore(threshold=0.5)})

# %%
# Evaluating the trained model
eval_test = model.evaluate(RGB_image_test, Mask_test)
# Out:
# 70/70 [==============================] - 2s 31ms/step

# %%
#print performances of the model on test images
print("Test Loss = " + str(eval_test[0]))
print("Test Metric = ",str(eval_test[1]),str(eval_test[2]),str(eval_test[3]))
# Out:
# Test Loss = 0.032966732872383935
# Test Metric =  0.590951144695282 0.7428600192070007 0.782540500164032

# %% [markdown]
#  ## B. Evaluation on Test DATA - method 2

# %%
Mask_test_pred_int= model.predict(RGB_image_test, verbose=2) #predict the masks, the output is a probability map

# %%
Treshold=0.5
Mask_test_pred_int_thres = (Mask_test_pred_int >Treshold).astype(np.uint8) #convert the probability map to an unit8 image using the threshold chosen

# %%
#compute the True positive  and recall
True_positive = np.zeros((Mask_test.shape[0]))
Recall = np.zeros((Mask_test.shape[0]))
for ix in range(Mask_test.shape[0]):
    True_positive[ix], Recall[ix] = performance(Mask_test_pred_int_thres[ix], Mask_test[ix])

# %%
#print performances of the model on test images
print("Mean True Positive:", True_positive.mean())
print("Mean Recall:",Recall.mean())
print("max True Positive:",True_positive.max())
print("max Recall:",Recall.max())
print("min True Positive:",True_positive.min())
print("min Recall:",Recall.min())
# Out:
# Mean True Positive: 0.7012479624577931
# Mean Recall: 0.7566140179123197
# max True Positive: 0.8992537260055542
# max Recall: 0.888561487197876
# min True Positive: 0.44565218687057495
# min Recall: 0.1981566846370697

# %% [markdown]
#  # **Step 8: Inference on unlabled data and save generated masks**

# %%
#Predict the masks of new images
Path_new_images=''
Path_to_save_masks=''
New_images=
Masks= model.predict(New_images, verbose=1)
Treshold=0.5
Mask_thres = (Masks >Treshold).astype(np.uint8)

for j in range(0,len(Mask_thres)):
   img1 = Masks[j, :, :, 0]
   fig = plt.imshow(~img1)
   plt.axis('off')
   fig.axes.get_xaxis().set_visible(False)
   fig.axes.get_yaxis().set_visible(False)
   plt.savefig(Path_to_save_masks+"{}.png".format(j), bbox_inches='tight', pad_inches = 0)
